# %%
import knn as knn
import pandas as pd
import numpy as np
import cross_validation as cv

# %%
data= pd.read_csv("/home/msc2/Documents/Academics 3rd Sem/MDSC-301/data/pulsar_data_train_18226.csv")
data.head()
# Out:
#     Mean of the integrated profile  \
# 0                       102.617188
# 1                       106.281250
# 2                       138.460938
# 3                       134.039062
# 4                       108.039062
#
#     Standard deviation of the integrated profile  \
# 0                                      49.692354
# 1                                      43.021785
# 2                                      48.917166
# 3                                      51.800459
# 4                                      34.910243
#
#     Excess kurtosis of the integrated profile  \
# 0                                    0.230439
# 1                                    0.408868
# 2                                   -0.039592
# 3                                   -0.195845
# 4                                    0.321157
#
#     Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 0                             0.193325                   1.489130
# ...

# %%
out= knn.normalize(data[' Standard deviation of the integrated profile '])
data['Standard deviation of the integrated profile_norm']= out['norm_data']
Gender_mean= out['mean']
Gender_std= out['std']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ' Standard deviation of the integrated profile '
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-6c125169d73e> in <module>
# ...
