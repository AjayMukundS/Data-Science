# %%
import pandas as pd
import numpy as np
import MLDecisionTree as dt

# %%
data= pd.read_csv("/home/msc2/Machine Learning Practicals/ML Assignment/pulsar_data_train_18226.csv")
data.head()
# Out:
#     Mean of the integrated profile  \
# 0                       102.617188
# 1                       106.281250
# 2                       138.460938
# 3                       134.039062
# 4                       108.039062
#
#     Standard deviation of the integrated profile  \
# 0                                      49.692354
# 1                                      43.021785
# 2                                      48.917166
# 3                                      51.800459
# 4                                      34.910243
#
#     Excess kurtosis of the integrated profile  \
# 0                                    0.230439
# 1                                    0.408868
# 2                                   -0.039592
# 3                                   -0.195845
# 4                                    0.321157
#
#     Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 0                             0.193325                   1.489130
# ...

# %%
dataset= data.iloc[:, :9].values
tree = dt.build_tree(dataset,5, 1)
dt.print_tree(tree)
# Out:
#  [Var03 < 0.6892155809999999]
#   [Var06 < 56.00214376]
#    [Var01 < 83.6796875]
#     [0.0]
#     [0.0]
#    [Var01 < 110.1953125]
#     [1.0]
#     [1.0]
#   [Var01 < 60.6328125]
#    [Var01 < 35.15625]
#     [Var01 < 11.9765625]
#      [Var01 < 8.2265625]
#       [1.0]
#       [1.0]
#      [Var01 < 11.9765625]
#       [1.0]
#       [1.0]
#     [Var01 < 35.15625]
#      [1.0]
#      [1.0]
#    [Var01 < 60.6328125]
#     [1.0]
#     [1.0]
